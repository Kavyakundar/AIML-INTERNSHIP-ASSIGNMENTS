# %% [markdown]
# ###Assignment Name: AI Around Me

# %% [markdown]
# 1.  **Google Maps** --
# I use it to find directions and avoid traffic. Machine learning analyzes traffic data and user movement patterns to predict congestion and suggest the fastest route.
# 2.   **Instagram** --
# The reels and posts shown to me are based on what I like and watch.
# Machine learning studies my likes, comments, and viewing time to personalize the content in my feed.
#
# 1.   **YouTube** --
# It recommends videos based on my watch history and the types of videos I spend more time watching.
# ML analyzes user behavior and engagement to suggest videos that match my interests.
# 2.   **Gmail** --
# Spam emails are automatically filtered.
# Machine learning identifies suspicious patterns in email content and senders to move unwanted emails to the spam folder.
#
#
# 1.   **Google Lens** --
# It identifies objects, text, or places through the camera.
# Machine learning and image recognition analyze the image and compare it with large datasets to recognize what is shown.
# 2.   **Google Photos** --
# It automatically organizes photos by recognizing faces, objects, and places.
# ML-based image recognition groups similar photos and helps in searching images easily.
#
#
# 1.   **Spotify** --
# It suggests songs and playlists based on the music I listen to regularly.
# Machine learning studies listening patterns and user preferences to recommend new songs.
# 2.   **Amazon** --
# When I search for a product, it recommends similar items.
# Machine learning analyzes browsing history, searches, and purchases to suggest products I might like.
#
#
# 1.   **Google Assistant** --
# I can give voice commands and ask questions.
# Natural language processing and ML help it understand speech and respond with relevant information.
# 2.   **Netflix** --
# It recommends movies and shows based on my viewing history and ratings.
# Machine learning analyzes what I watch and suggests content similar to my interests.
