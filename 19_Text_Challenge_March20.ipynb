# %% [markdown]
# #TEXT CHALLENGE
#
#
# ####1.   Hiiii brooo hw r uuu 😁
#
# **Issues**: Slang (hw, r), repeated letters, emoji
#
# **Preprocessing**: Expand words, remove emoji, normalize repeated characters
#
#
#
# ---
#
#
#
#
# ####2.   I dnt lyk dis movie 😒
#
# **Issues**: Slang (dnt, lyk, dis), emoji
#
# **Preprocessing**: Convert to “I do not like this movie”, remove emoji
#
#
# ---
#
#
#
# ####3.   Gm dearrr hv a gr8 day 🌸
#
# **Issues**: Slang (Gm, hv, gr8), repeated letters, emoji
#
# **Preprocessing**: Expand words, remove emoji, normalize text
#
#
# ---
#
#
#
# ####4.   Whaaat is thisss???
#
# **Issues**: Repeated letters
#
# **Preprocessing**: Reduce repeated characters
#
#
# ---
#
#
#
# ####5.   Omg!!! u nailed it 🔥🔥
#
# **Issues**: Slang (Omg, u), emoji
#
# **Preprocessing**: Convert to proper words, remove emoji
#
#
# ---
#
#
#
# ####6.   Im feelin sooo sleepy 😴
#
# **Issues**: Slang (feelin), repeated letters, emoji
#
# **Preprocessing**: Correct to “feeling”, normalize text, remove emoji
#
#
# ---
#
#
#
# ####7.   Plsss call me asappp!!!
#
# **Issues**: Slang (Plsss, asappp), repeated letters
#
# **Preprocessing**: Normalize to “Please call me ASAP”
#
#
# ---
#
#
#
# ####8.   Wer r u goinggg??
#
# **Issues**: Typos (Wer), slang (r, u), repeated letters
#
# **Preprocessing**: Correct spelling, expand words
#
#
# ---
#
#
#
# ####9.   LOLzz this is too gud 😂
#
# **Issues**: Slang (LOLzz, gud), emoji
#
# **Preprocessing**: Replace with standard words, remove emoji
#
#
# ---
#
#
#
# ####10.   Ill b there soooon 👍
#
# **Issues**: Slang (b), repeated letters, emoji
#
# **Preprocessing**: Expand words, normalize text, remove emoji
#
#
# ---
#
#
#
# ####11.   Thnk u sooo muchhh!!!
#
# **Issues**: Typo (Thnk), repeated letters
#
# **Preprocessing**: Correct spelling, reduce repetition
#
#
# ---
#
#
#
# ####12.   Yaar this is awsm 😎
#
# **Issues**: Slang (awsm), emoji
#
# **Preprocessing**: Replace with “awesome”, remove emoji
#
#
# ---
#
#
#
#
# ####13.   Cant w8 to seee uuuu
#
# **Issues**: Slang (w8, u), repeated letters
#
# **Preprocessing**: Expand and normalize text
#
#
# ---
#
#
#
#
# ####14.   Dis place iss sooo coolll
#
# **Issues**: Slang (Dis), repeated letters
#
# **Preprocessing**: Convert to “This place is so cool”
#
#
# ---
#
#
#
#
# ####15.   He iz veryyy smarttt
#
# **Issues**: Typos (iz), repeated letters
#
# **Preprocessing**: Correct spelling, normalize
#
#
# ---
#
#
#
#
# ####16.   U shud tryyy thisss recipe
#
# **Issues**: Slang (U, shud), repeated letters
#
# **Preprocessing**: Expand words, normalize text
#
#
# ####17.   Im sooo happpyyy today 😊
#
# **Issues**: Repeated letters, emoji
#
# **Preprocessing**: Normalize text, remove emoji
#
#
# ---
#
#
#
#
# ####18.   Noooo pls donttt gooo
#
# **Issues**: Repeated letters, typo (donttt)
#
# **Preprocessing**: Normalize and correct spelling
#
#
# ---
#
#
#
#
# ####19.   Txt me whn u freee
#
# **Issues**: Slang (Txt, whn, u), repeated letters
#
# **Preprocessing**: Expand to full words
#
#
# ---
#
#
#
#
# ####20.   Hbd brooo 🎉🎉
#
# **Issues**: Slang (Hbd, brooo), emoji
#
# **Preprocessing**: Convert to “Happy Birthday bro”, remove emoji

# %% [markdown]
# ##Preprocessing is needed to:
#
# *   Improve text readability
# *   Handle slang and abbreviations
# *   Correct spelling mistakes
# *   Remove unnecessary symbols/emojis
# *   Standardize text format
# *   Improve NLP tasks like sentiment analysis, emotion detection, chatbots, and text classification
