# %%
#Build a Text Cleaner
import string


stopwords={
    "a", "an", "the", "is", "are", "in", "on", "at", "for", "to",
    "and", "or", "of", "this", "that", "it", "be"
}

def clean_text(text):
    #Convert to lowercase
    text=text.lower()

    #Remove punctuation
    text=text.translate(str.maketrans('', '',string.punctuation))

    #Tokenize
    words=text.split()

    #Remove stopwords
    cleaned_words=[word for word in words if word not in stopwords]

    #Join words
    return " ".join(cleaned_words)



sample_text="Data Science is an exciting field! It involves analysis, visualization, and building intelligent systems."

result=clean_text(sample_text)

print("Original Text:")
print(sample_text)

print("\nCleaned Text:")
print(result)
# Out:
# Original Text:
# Data Science is an exciting field! It involves analysis, visualization, and building intelligent systems.
#
# Cleaned Text:
# data science exciting field involves analysis visualization building intelligent systems
