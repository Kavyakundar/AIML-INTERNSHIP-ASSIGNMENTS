# %%
# Student Data Manager
students={}
for i in range(5):
    print("\nEnter details of student",i+1)
    name=input("Enter name: ")
    marks=float(input("Enter marks: "))
    students[name]=marks

topper=max(students,key=students.get)
average=sum(students.values())/len(students)

print("\nStudent details:",students)
print("Topper is",topper,"with",students[topper],"marks")
print("Class average is",round(average,2))

print("\nGrades of students:")
for name,marks in students.items():
    if marks>=90:
        grade="A"
    elif marks>=75:
        grade="B"
    elif marks>=60:
        grade="C"
    elif marks>=40:
        grade="D"
    else:
        grade="F"
    print(name,"got grade",grade)
# Out:
# Enter details of student 1
# Enter name: Kavya
# Enter marks: 91
#
# Enter details of student 2
# Enter name: Divya
# Enter marks: 75
#
# Enter details of student 3
# Enter name: Aadhi
# Enter marks: 66
#
# Enter details of student 4
# Enter name: Aparna
# Enter marks: 23
#
# Enter details of student 5
# Enter name: Vinu
# Enter marks: 98
#
# Student details: {'Kavya': 91.0, 'Divya': 75.0, 'Aadhi': 66.0, 'Aparna': 23.0, 'Vinu': 98.0}
# Topper is Vinu with 98.0 marks
# Class average is 70.6
#
# Grades of students:
# Kavya got grade A
# Divya got grade B
# Aadhi got grade C
# Aparna got grade F
# Vinu got grade A
